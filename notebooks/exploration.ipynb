# %% [markdown]
# # Exploration
#
# Starter notebook for data exploration.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Load your data here
# df = pd.read_csv('...')
# df.head()
